# %% [markdown]
# <a href="https://colab.research.google.com/github/wooruan/tecnicas_de_prog/blob/main/Eng_soft_13nov_pedro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LISTA 2 CONDICIONAL

# %%
'''  Elabore um programa que solicite ao usuário um número real e ao final imprima na tela se o
número informado é maior que 10 (dez)'''
print("digite um numero")
num = int(input("digite um numero"))
if num > 10:
  print("O número é maior que 10")
else:
  print ("nao é maior")
# Out:
# digite um numero
# digite um numero4
# nao é maior

# %%
'''Escreva um programa que solicite ao usuário um número real e ao final imprima na tela se
o número informado é maior ou igual a dez ou menor que 10 (dez)'''
print ()
num = int(input("digite um numero"))
if num > 10:
  print ("o numero é maior ou igual")
elif num == 10:
  print ("o numero é igual")
else:
  print ("o numero é menor")
# Out:
# digite um numero4
# o numero é menor

# %%
'''Elabore um algoritmo que solicite ao usuário um número real e ao final imprima na tela se o
número informado é maior que dez, se é menor que dez, ou se é igual a dez'''
print ()
num = float(input("digite um numero"))
if num > 10:
  print ("o numero é maior")
elif num == 10:
  print ("o numero é igual")
else:
  print ("o numero é menor")
#
# Out:
# digite um numero7
# o numero é menor

# %%
'''Elabore um algoritmo que leia um número inteiro e imprima uma das mensagens: é múltiplo
de 3, ou, não é múltiplo de 3'''
print ()
num = int(input("digite um numwro"))
if num % 3 == 0:
  print ("o numero é multiplo de 3")
else:
  print ("o numero não é multiplo de 3")
# Out:
# digite um numwro0
# o numero é multiplo de 3

# %%
'''Refazer o exercício anterior, solicitando antes o múltiplo a ser testado'''
print ()
num = int(input("digite um numero"))
mult = int(input("digite o multiplo"))
if num % mult == 0:
  print ("o numero é multiplo de ", num)
else:
  print ("o numero não é multiplo de ", mult)
# Out:
# digite um numero10
# digite o multiplo10
# o numero é multiplo de  10

# %%
'''Desenvolva um algoritmo que classifique um número inteiro fornecido pelo usuário como
par ou ímpar'''
